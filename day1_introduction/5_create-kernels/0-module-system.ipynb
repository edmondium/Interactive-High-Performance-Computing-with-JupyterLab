# %% [markdown]
# ![jsc-logo.jpg](attachment:67258d94-84e6-4a0c-ae8f-c74332ec082e.jpg)
# Author: [Jens Henrik Göbbert](mailto:j.goebbert@fz-juelich.de)
# ------------------------------------

# %% [markdown]
# ## Lmod (Lua-based Modules) for managing environment modules
#
# On a “normal” workstation software is provided in general on system level once. It is not required that any distinct shell can change fundamental settings.
# HPC systems need to support multiple versions software packages:
# - Compilers (e.g. gcc, icc, clang)
# - libraries (e.g. MPI, HDF5)
# - software (e.g. Python)
#
# Switching between modules is done by
# - Change environment variables (most prominent PATH and LD_LIBRARY_PATH)
# - Ensure that dependencies to other modules are fulfilled.
#     - unload/load modules which conflict/required
#
# ![image.png](attachment:3d953eb6-219f-48db-baff-af73e99f20e4.png)
#
# -------------------------------------------------------

# %%
module list

# %%
module purge

# %%
module list

# %%
module spider OpenCV

# %%
module spider OpenCV/4.5.5-contrib

# %%
module load Stages/2024

# %%
module load GCCcore/.12.3.0

# %%
echo $MODULEPATH

# %%
ls /p/software/$SYSTEMNAME/stages/2024/modules/all/Compiler/GCCcore/12.3.0

# %%
ls /p/software/$SYSTEMNAME/stages/2024/modules/all/Compiler/GCCcore/12.3.0/OpenCV

# %%
module load OpenCV/4.8.1-contrib

# %%
module list

# %%
cat /p/software/$SYSTEMNAME/stages/2024/modules/all/Compiler/GCCcore/12.3.0/OpenCV/4.8.1-contrib.lua

# %%
echo $EBROOTOPENCV

# %%
ls -la $EBROOTOPENCV

# %%
ls -la $EBROOTOPENCV/easybuild

# %%
cat $EBROOTOPENCV/easybuild/OpenCV-4.8.1-gcccoreflexiblas-12.3.0-3.3.1-contrib.eb

# %% [markdown]
# ## Public easybuild repository of JSC:
# https://github.com/easybuilders/JSC
